# %%
# %matplotlib inline
import pandas as ps
import numpy as np
from matplotlib import pyplot as plt
from sklearn.cluster import DBSCAN
train = ps.read_csv('/home/sergio/Data/titanic/train.csv')
test = ps.read_csv('/home/sergio/Data/titanic/test.csv')
fulldata = ps.concat([train.drop(["Survived"], axis=1), test])
train[:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # Гистограммы значений

# %%
from math import log
def print_and_plot(data, column, step=None, base=None, ax=None):
    data = data[[column,"Survived"]].dropna()
    if step is not None:
        data[column] = [(int(row[column]//step * step),int(row[column]//step * step)+step)
                        for ind, row in data.iterrows()]
    elif base is not None:
        data[column] = [(base**int(log(row[column],base)), base**int(log(row[column],base)+1))
                        if row[column] != 0 else (0,0)
                        for ind, row in data.iterrows()]
    data = data.groupby([column, 'Survived'])[column].count().unstack('Survived').fillna(0, axis="columns")
    plot = data.plot(kind='bar', stacked=True, rot=(90 if any([step,base]) else 0), ax=ax)
    cols = data.columns
    data.insert(len(cols), "Count", [sum(x for x in row) for ind, row in data.iterrows()])
    for col in cols:
        data[col] = data[col].astype(np.float64) / data["Count"]
    return data

# %%
fig, axes = plt.subplots(nrows=3, ncols=3)
fig.set_size_inches(15,15)
train.Survived.value_counts().sort_index().plot(kind='bar', rot=0, ax=axes[0,0])
tables = [
    print_and_plot(train, "Sex", ax=axes[0,1]),
    print_and_plot(train, "Pclass", ax=axes[0,2]),
    print_and_plot(train, "Age", step=4, ax=axes[1,0]),
    print_and_plot(train, "SibSp", ax=axes[1,1]),
    print_and_plot(train, "Parch", ax=axes[1,2]),
    print_and_plot(train, "Embarked", ax=axes[2,0]),
    print_and_plot(train, "Fare", base=3, ax=axes[2,1])
]
fig.tight_layout()

# %%
for table in tables:
    print(table, "\n")
# Out:
# Survived         0         1  Count
# Sex
# female    0.257962  0.742038    314
# male      0.811092  0.188908    577
#
# Survived         0         1  Count
# Pclass
# 1         0.370370  0.629630    216
# 2         0.527174  0.472826    184
# 3         0.757637  0.242363    491
#
# Survived         0         1  Count
# Age
# (0, 4)    0.333333  0.666667     30
# (4, 8)    0.300000  0.700000     20
# (8, 12)   0.722222  0.277778     18
# (12, 16)  0.333333  0.666667     15
# (16, 20)  0.629630  0.370370     81
# (20, 24)  0.710843  0.289157     83
# (24, 28)  0.577778  0.422222     90
# (28, 32)  0.637363  0.362637     91
# (32, 36)  0.521739  0.478261     69
# (36, 40)  0.592593  0.407407     54
# (40, 44)  0.615385  0.384615     39
# (44, 48)  0.742857  0.257143     35
# (48, 52)  0.468750  0.531250     32
# (52, 56)  0.555556  0.444444     18
# (56, 60)  0.615385  0.384615     13
# (60, 64)  0.538462  0.461538     13
# (64, 68)  1.000000  0.000000      6
# ...

# %% [markdown]
# ## Количество людей по заполненности поля Age

# %%
tmp = train.copy()
tmp.insert(len(tmp.columns), "hasAge", [0 if np.isnan(age) else 1 for age in tmp.Age])
print_and_plot(tmp, "hasAge")
# Out:
# Survived         0         1  Count
# hasAge
# 0         0.706215  0.293785    177
# 1         0.593838  0.406162    714

# %% [markdown]
# ## Количество людей по SibSp + Parch

# %%
sp = train.copy()
sp.insert(len(sp.columns), "SibPar", [row.SibSp + row.Parch for ind, row in sp.iterrows()])
print_and_plot(sp, "SibPar")
# Out:
# Survived         0         1  Count
# SibPar
# 0         0.696462  0.303538    537
# 1         0.447205  0.552795    161
# 2         0.421569  0.578431    102
# 3         0.275862  0.724138     29
# 4         0.800000  0.200000     15
# 5         0.863636  0.136364     22
# 6         0.666667  0.333333     12
# 7         1.000000  0.000000      6
# 10        1.000000  0.000000      7

# %% [markdown]
# ## Количество людей по префиксу номера билета

# %%
def is_num(x):
    try:
        int(x)
    except ValueError:
        return False
    else:
        return True
prefix = lambda ticket: ticket.split()[0].split(".")[0].split("/")[0] if not is_num(ticket) else "None"
tmp = train.copy()
tmp.insert(len(tmp.columns), "TicketPrefix", [prefix(ticket) for ticket in tmp.Ticket])
print_and_plot(tmp, "TicketPrefix")
# Out:
# Survived             0         1  Count
# TicketPrefix
# A             0.928571  0.071429     28
# A4            1.000000  0.000000      1
# C             0.545455  0.454545     33
# CA            0.928571  0.071429     14
# F             0.333333  0.666667      6
# Fa            1.000000  0.000000      1
# LINE          0.750000  0.250000      4
# None          0.615734  0.384266    661
# P             0.500000  0.500000      2
# PC            0.350000  0.650000     60
# PP            0.333333  0.666667      3
# S             0.857143  0.142857     14
# SC            0.461538  0.538462     13
# SCO           1.000000  0.000000      1
# SO            0.000000  1.000000      1
# SOTON         0.882353  0.117647     17
# STON          0.555556  0.444444     18
# SW            0.000000  1.000000      1
# W             0.909091  0.090909     11
# WE            0.500000  0.500000      2

# %% [markdown]
# ## Количество людей по существованию префикса в номере билета

# %%
tmp.insert(len(tmp.columns), "HasTicketPrefix", [prefix(ticket) != "None" for ticket in tmp.Ticket])
print_and_plot(tmp, "HasTicketPrefix")
# Out:
# Survived                0         1  Count
# HasTicketPrefix
# False            0.615734  0.384266    661
# True             0.617391  0.382609    230

# %% [markdown]
# ## Количество людей по палубе

# %%
deck = lambda cabin: cabin[0].upper() if type(cabin) == str else "-"
tmp = train.copy()
tmp.insert(len(tmp.columns), "Deck", [deck(cabin) for cabin in tmp.Cabin])
print_and_plot(tmp, "Deck")
# Out:
# Survived         0         1  Count
# Deck
# -         0.700146  0.299854    687
# A         0.533333  0.466667     15
# B         0.255319  0.744681     47
# C         0.406780  0.593220     59
# D         0.242424  0.757576     33
# E         0.250000  0.750000     32
# F         0.384615  0.615385     13
# G         0.500000  0.500000      4
# T         1.000000  0.000000      1

# %% [markdown]
# ## Количество людей по существованию палубы

# %%
tmp = train.copy()
tmp.insert(len(tmp.columns), "Deck", ["Yes" if type(cabin) == str else "No" for cabin in tmp.Cabin])
print_and_plot(tmp, "Deck")
# Out:
# Survived         0         1  Count
# Deck
# No        0.700146  0.299854    687
# Yes       0.333333  0.666667    204

# %% [markdown]
# ## Количество людей по титулу

# %%
title = lambda name: name.split(",")[1].split(".")[0].strip()
tmp = train.copy()
tmp.insert(len(tmp.columns), "Title", [title(name) for name in tmp.Name])
print_and_plot(tmp, "Title")
# Out:
# Survived             0         1  Count
# Title
# Capt          1.000000  0.000000      1
# Col           0.500000  0.500000      2
# Don           1.000000  0.000000      1
# Dr            0.571429  0.428571      7
# Jonkheer      1.000000  0.000000      1
# Lady          0.000000  1.000000      1
# Major         0.500000  0.500000      2
# Master        0.425000  0.575000     40
# Miss          0.302198  0.697802    182
# Mlle          0.000000  1.000000      2
# Mme           0.000000  1.000000      1
# Mr            0.843327  0.156673    517
# Mrs           0.208000  0.792000    125
# Ms            0.000000  1.000000      1
# Rev           1.000000  0.000000      6
# Sir           0.000000  1.000000      1
# the Countess  0.000000  1.000000      1

# %% [markdown]
# ## Количество людей по сгруппированному титулу

# %%
mapping = {
    "mister": {"Capt", "Col", "Don", "Dr", "Jonkheer", "Major", "Mr", "Rev", "Sir"}, # Взрослые мужчины
    "missis": {"Mme", "Mrs", "Dona", "the Countess"}, # Взрослые женщины
    "miss": {"Lady", "Miss", "Mlle", "Ms"}, # Девочки и девушки
    "master": {"Master"} # Мальчики и юноши
}
title_mapping = lambda title: next(key for key, value in mapping.items() if title in value)
tmp.insert(len(tmp.columns), "TitleMapped", [title_mapping(title) for title in tmp.Title])
print_and_plot(tmp, "TitleMapped")
# Out:
# Survived            0         1  Count
# TitleMapped
# master       0.425000  0.575000     40
# miss         0.295699  0.704301    186
# missis       0.204724  0.795276    127
# mister       0.838290  0.161710    538

# %% [markdown]
# ## Количество людей по числу людей на один билет

# %%
ticketsCount = train.groupby(["Ticket"])["PassengerId"].count()
tmp = train.copy()
tmp.insert(len(tmp.columns), "Cotravellers", [ticketsCount[ticket] for ticket in tmp.Ticket])
print_and_plot(tmp, "Cotravellers")
# Out:
# Survived             0         1  Count
# Cotravellers
# 1             0.702011  0.297989    547
# 2             0.425532  0.574468    188
# 3             0.301587  0.698413     63
# 4             0.500000  0.500000     44
# 5             1.000000  0.000000     10
# 6             1.000000  0.000000     18
# 7             0.761905  0.238095     21

# %% [markdown]
# ## Количество людей по цене за один билет

# %%
ticketsCount = train.groupby(["Ticket"])["PassengerId"].count()
tmp = train.copy()
tmp.insert(len(tmp.columns), "FarePerTraveller", [row.Fare/ticketsCount[row.Ticket] for ind, row in tmp.iterrows()])
print_and_plot(tmp, "FarePerTraveller", base=3)
# Out:
# Survived                 0         1  Count
# FarePerTraveller
# (0, 0)            0.933333  0.066667     15
# (3, 9)            0.743649  0.256351    433
# (9, 27)           0.559567  0.440433    277
# (27, 81)          0.359477  0.640523    153
# (81, 243)         0.230769  0.769231     13

# %% [markdown]
# ## Количество люедй по числу кают

# %%
tmp = train.copy()
tmp.insert(len(tmp.columns), "NumCabins", [len(cabin.split()) if type(cabin) == str else 0 for cabin in tmp.Cabin])
print_and_plot(tmp, "NumCabins")
# Out:
# Survived          0         1  Count
# NumCabins
# 0          0.700146  0.299854    687
# 1          0.322222  0.677778    180
# 2          0.437500  0.562500     16
# 3          0.500000  0.500000      6
# 4          0.000000  1.000000      2

# %% [markdown]
# ## Количество людей по числу однофамильцев

# %%
surname = lambda name: name.split(",")[0].strip()
tmp = train.copy()
tmp.insert(len(tmp.columns), "Surname", [surname(name) for name in tmp.Name])
surnamesCount = tmp.groupby(["Surname"])["PassengerId"].count()
tmp.insert(len(tmp.columns), "SurnameCount", [surnamesCount[surname] for surname in tmp.Surname])
print_and_plot(tmp, "SurnameCount")
# Out:
# Survived             0         1  Count
# SurnameCount
# 1             0.640449  0.359551    534
# 2             0.475904  0.524096    166
# 3             0.642857  0.357143     84
# 4             0.571429  0.428571     56
# 5             1.000000  0.000000      5
# 6             0.766667  0.233333     30
# 7             1.000000  0.000000      7
# 9             0.777778  0.222222      9

# %% [markdown]
# ## Количество людей по числу дальних родственников

# %%
surname = lambda name: name.split(",")[0].strip()
tmp = train.copy()
tmp.insert(len(tmp.columns), "Surname", [surname(name) for name in tmp.Name])
surnamesCount = tmp.groupby(["Surname"])["PassengerId"].count()
tmp.insert(len(tmp.columns), "FarRelatives", [surnamesCount[row.Surname]-row.SibSp-row.Parch for ind, row in tmp.iterrows()])
print_and_plot(tmp, "FarRelatives")
# Out:
# Survived             0         1  Count
# FarRelatives
# -3            1.000000  0.000000      7
# -2            0.125000  0.875000      8
# -1            0.452381  0.547619     42
#  0            0.442623  0.557377    122
#  1            0.653448  0.346552    580
#  2            0.712121  0.287879     66
#  3            0.692308  0.307692     39
#  4            0.476190  0.523810     21
#  5            1.000000  0.000000      2
#  6            1.000000  0.000000      3
#  9            0.000000  1.000000      1

# %% [markdown]
# ## Количество людей в тестовой выборке, связанных с людьми в тренировочной

# %%
surname = lambda name: name.split(",")[0].strip()
tmp = train.copy()
tmp_test = test.copy()
tmp.insert(len(tmp.columns), "Surname", [surname(name) for name in tmp.Name])
tmp_test.insert(len(tmp_test.columns), "Surname", [surname(name) for name in tmp_test.Name])

trainSurnamesCount = dict(tmp.groupby(["Surname"])["PassengerId"].count())
trainTicketsCount = dict(tmp.groupby(["Ticket"])["PassengerId"].count())
surnameAndTicketCount = dict(tmp.groupby(["Ticket", "Surname"])["PassengerId"].count())

linked_by_surname = lambda row: trainSurnamesCount.get(surname(row.Name), 0)
linked_by_ticket = lambda row: trainTicketsCount.get(row.Ticket, 0)
linked_by_surname_and_ticket = lambda row: surnameAndTicketCount.get((row.Ticket, row.Surname), 0)
num_linked = lambda row: linked_by_surname(row) + linked_by_ticket(row) - linked_by_surname_and_ticket(row)

linked_people = sum(1 for ind, row in tmp_test.iterrows() if num_linked(row) > 0)
linked_people_surname = sum(1 for ind, row in tmp_test.iterrows() if linked_by_surname(row) > 0)
linked_people_ticket = sum(1 for ind, row in tmp_test.iterrows() if linked_by_ticket(row) > 0)
linked_people_both = sum(1 for ind, row in tmp_test.iterrows() if linked_by_surname_and_ticket(row) > 0)

linked_train = sum(num_linked(row) for ind, row in tmp_test.iterrows())
linked_train_surname = sum(linked_by_surname(row) for ind, row in tmp_test.iterrows())
linked_train_ticket = sum(linked_by_ticket(row) for ind, row in tmp_test.iterrows())
linked_train_both = sum(linked_by_surname_and_ticket(row) for ind, row in tmp_test.iterrows())

print("Linked people in test data: {}/{} (by surname {}, by ticket {}, by both {})".format(
        linked_people, len(test), linked_people_surname, linked_people_ticket, linked_people_both))
print("Linked people in training data: {}/{} (by surname {}, by ticket {}, by both {})".format(
        linked_train, len(train), linked_train_surname, linked_train_ticket, linked_train_both))
# Out:
# Linked people in test data: 215/418 (by surname 188, by ticket 152, by both 118)
# Linked people in training data: 443/891 (by surname 359, by ticket 297, by both 213)

# %%
pas = tmp_test[tmp_test.PassengerId == 896].iloc[0]
tmp[(tmp.Ticket == pas.Ticket) & (tmp.Surname == pas.Surname)]
# Out:
#      PassengerId  Survived  Pclass                      Name     Sex  Age  \
# 479          480         1       3  Hirvonen, Miss. Hildur E  female    2
#
#      SibSp  Parch   Ticket     Fare Cabin Embarked   Surname
# 479      0      1  3101298  12.2875   NaN        S  Hirvonen

# %% [markdown]
# ## Добавление индекса выживания по номеру билета

# %%
tickets_survival = {ticket: {"survived": 0, "perished": 0} for ticket in train.Ticket.drop_duplicates()}
for ind, row in train.iterrows():
    if row.Survived:
        tickets_survival[row.Ticket]["survived"] += 1
    else:
        tickets_survival[row.Ticket]["perished"] += 1

def ticket_survival_index(row):
    info = tickets_survival[row.Ticket]
    index = lambda surv, per: surv - per
    if row.Survived:
        return index(info["survived"]-1, info["perished"])
    else:
        return index(info["survived"], info["perished"]-1)

tmp = train.copy()
tmp.insert(len(tmp.columns), "TicketSurvivalIndex", [ticket_survival_index(row) for ind, row in tmp.iterrows()])
print_and_plot(tmp, "TicketSurvivalIndex")
# Out:
# Survived                    0         1  Count
# TicketSurvivalIndex
# -6                   1.000000  0.000000     14
# -5                   1.000000  0.000000     18
# -4                   1.000000  0.000000     10
# -3                   0.923077  0.076923     13
# -2                   0.857143  0.142857      7
# -1                   0.609195  0.390805     87
#  0                   0.676007  0.323993    571
#  1                   0.280992  0.719008    121
#  2                   0.297297  0.702703     37
#  3                   0.272727  0.727273     11
#  4                   1.000000  0.000000      2

# %% [markdown]
# ## Добавление индекса выживания по фамилии

# %%
surname = lambda name: name.split(",")[0].strip()
tmp = train.copy()
tmp.insert(len(tmp.columns), "Surname", [surname(name) for name in tmp.Name])

surnames_survival = {surname: {"survived": 0, "perished": 0} for surname in tmp.Surname.drop_duplicates()}
for ind, row in tmp.iterrows():
    if row.Survived:
        surnames_survival[row.Surname]["survived"] += 1
    else:
        surnames_survival[row.Surname]["perished"] += 1

def surname_survival_index(row):
    info = surnames_survival[row.Surname]
    index = lambda surv, per: surv - per
    if row.Survived:
        return index(info["survived"]-1, info["perished"])
    else:
        return index(info["survived"], info["perished"]-1)


tmp.insert(len(tmp.columns), "SurnameSurvivalIndex", [surname_survival_index(row) for ind, row in tmp.iterrows()])
print_and_plot(tmp, "SurnameSurvivalIndex")
# Out:
# Survived                     0         1  Count
# SurnameSurvivalIndex
# -6                    0.777778  0.222222      9
# -5                    1.000000  0.000000     18
# -4                    1.000000  0.000000     12
# -3                    0.888889  0.111111     18
# -2                    0.810811  0.189189     37
# -1                    0.617021  0.382979     94
#  0                    0.626761  0.373239    568
#  1                    0.321429  0.678571    112
#  2                    0.769231  0.230769     13
#  3                    0.600000  0.400000     10

# %% [markdown]
# ## Добавление индекса выживания по билету и фамилии

# %%
surname = lambda name: name.split(",")[0].strip()
tmp = train.copy()
tmp.insert(len(tmp.columns), "SurnameAndTicket", [(surname(row.Name), row.Ticket) for ind, row in tmp.iterrows()])

surtick_survival = {surtick: {"survived": 0, "perished": 0} for surtick in tmp.SurnameAndTicket.drop_duplicates()}
for ind, row in tmp.iterrows():
    if row.Survived:
        surtick_survival[row.SurnameAndTicket]["survived"] += 1
    else:
        surtick_survival[row.SurnameAndTicket]["perished"] += 1

def surtick_survival_index(row):
    info = surtick_survival[row.SurnameAndTicket]
    index = lambda surv, per: surv - per
    if row.Survived:
        return index(info["survived"]-1, info["perished"])
    else:
        return index(info["survived"], info["perished"]-1)


tmp.insert(len(tmp.columns), "SurtickIndex", [surtick_survival_index(row) for ind, row in tmp.iterrows()])
print_and_plot(tmp, "SurtickIndex")
# Out:
# Survived             0         1  Count
# SurtickIndex
# -6            1.000000  0.000000     14
# -5            1.000000  0.000000     18
# -4            1.000000  0.000000      5
# -3            1.000000  0.000000     12
# -2            0.857143  0.142857      7
# -1            0.500000  0.500000     60
#  0            0.642424  0.357576    660
#  1            0.329670  0.670330     91
#  2            0.600000  0.400000     15
#  3            0.111111  0.888889      9

# %% [markdown]
# ## Исследование влияния номера билета на выживаемость

# %%
def ticketIndex(ticket):
    if ticket == "LINE": return -500
    return int(ticket.split()[-1])
tickets = ps.Series([ticketIndex(ticket) for ticket in fulldata.Ticket.drop_duplicates()])
tickets.describe()
# Out:
# count        929.000000
# mean      321339.207750
# std       673254.000281
# min         -500.000000
# 25%        17421.000000
# 50%       113796.000000
# 75%       348123.000000
# max      3101317.000000
# dtype: float64

# %%
df = ps.DataFrame()
df.insert(0, "Ticket", tickets)
db = DBSCAN(eps=1, min_samples=2).fit(df)
labels = set(db.labels_)
print("Number of clusters: {}".format(len(labels)))
ticket_cluster = {ticket: db.labels_[i] for i, ticket in enumerate(df.Ticket)}
cluster_tickets = {cluster: [ticket for ticket, cls in ticket_cluster.items() if cls == cluster]
                   for cluster in ticket_cluster.values()}
# Out:
# Number of clusters: 129

# %%
ticket_cluster
# Out:
# {-500: -1,
#  2: 122,
#  3: 122,
#  251: -1,
#  541: -1,
#  680: -1,
#  693: 101,
#  694: 101,
#  695: 101,
#  751: 65,
#  752: 65,
#  851: -1,
#  1166: -1,
#  1222: -1,
#  1478: -1,
#  1585: -1,
#  1588: -1,
#  1601: -1,
#  1748: -1,
#  2003: -1,
#  2079: -1,
#  2123: -1,
#  2131: -1,
#  2133: -1,
#  2144: -1,
#  2146: 102,
#  2147: 102,
#  2148: 102,
#  2149: 102,
#  2151: 9,
#  2152: 9,
#  2159: -1,
#  2163: -1,
#  2166: 80,
#  2167: 80,
#  2168: 80,
#  2223: -1,
#  2314: 39,
#  2315: 39,
#  2343: -1,
#  2466: -1,
#  2543: -1,
#  2620: 46,
#  2621: 46,
#  2622: 46,
#  2623: 46,
#  2624: 46,
#  2625: 46,
#  2626: 46,
#  2627: 46,
#  2628: 46,
#  2629: 46,
#  2631: -1,
#  2641: -1,
#  2647: 14,
#  2648: 14,
#  2649: 14,
#  2650: 14,
#  2651: 14,
#  2652: 14,
#  2653: 14,
#  2654: 14,
#  2655: 14,
#  2656: 14,
#  2657: 14,
#  2658: 14,
#  2659: 14,
#  2660: 14,
#  2661: 14,
#  2662: 14,
#  2663: 14,
#  2664: 14,
#  2665: 14,
#  2666: 14,
#  2667: 14,
#  2668: 14,
#  2669: 14,
# ...

# %%
cluster_tickets
# Out:
# {-1: [233478,
#   323592,
#   2079,
#   30769,
#   365235,
#   36928,
#   6212,
#   2123,
#   18509,
#   3085,
#   31416,
#   2131,
#   2133,
#   28004,
#   2144,
#   9232,
#   36963,
#   237668,
#   36973,
#   2163,
#   366713,
#   374910,
#   243847,
#   368783,
#   383121,
#   368323,
#   233639,
#   12460,
#   2223,
#   358585,
#   383162,
#   329944,
#   110813,
#   237798,
#   34651,
#   367655,
#   10482,
#   239865,
#   251,
#   4348,
#   233734,
#   36568,
#   39186,
#   8471,
#   368402,
#   8475,
#   18723,
#   2343,
#   364846,
#   364856,
#   45380,
#   343095,
#   19924,
#   29011,
#   223596,
#   29037,
#   323951,
#   371060,
#   334912,
#   113028,
#   233866,
#   219533,
#   113038,
#   27042,
#   113059,
#   244346,
#   342441,
#   363592,
#   35273,
#   2466,
#   6563,
#   374887,
#   4579,
#   231919,
#   26707,
#   29178,
#   111361,
#   231945,
#   244252,
#   541,
#   14879,
#   363611,
#   14885,
#   14888,
#   244270,
#   3701,
#   244278,
#   336439,
# ...

# %%
listed = list(db.labels_)
cluster_counts = {label: listed.count(label) for label in labels}
for label, count in cluster_counts.items():
    print("{}: {} tickets".format(label, count))
# Out:
# 0: 5 tickets
# 1: 12 tickets
# 2: 37 tickets
# 3: 2 tickets
# 4: 4 tickets
# 5: 4 tickets
# 6: 2 tickets
# 7: 3 tickets
# 8: 2 tickets
# 9: 2 tickets
# 10: 24 tickets
# 11: 8 tickets
# 12: 5 tickets
# 13: 3 tickets
# 14: 55 tickets
# 15: 2 tickets
# 16: 7 tickets
# 17: 2 tickets
# 18: 57 tickets
# 19: 2 tickets
# 20: 11 tickets
# 21: 2 tickets
# 22: 2 tickets
# 23: 10 tickets
# 24: 3 tickets
# 25: 2 tickets
# 26: 5 tickets
# 27: 7 tickets
# 28: 4 tickets
# 29: 2 tickets
# 30: 5 tickets
# 31: 5 tickets
# 32: 5 tickets
# 33: 2 tickets
# 34: 3 tickets
# 35: 2 tickets
# 36: 2 tickets
# 37: 8 tickets
# 38: 2 tickets
# 39: 2 tickets
# 40: 3 tickets
# 41: 8 tickets
# 42: 2 tickets
# 43: 3 tickets
# 44: 2 tickets
# 45: 6 tickets
# 46: 10 tickets
# 47: 2 tickets
# 48: 8 tickets
# 49: 3 tickets
# 50: 3 tickets
# 51: 2 tickets
# 52: 2 tickets
# 53: 4 tickets
# 54: 17 tickets
# 55: 2 tickets
# 56: 8 tickets
# 57: 3 tickets
# 58: 4 tickets
# 59: 2 tickets
# 60: 4 tickets
# 61: 2 tickets
# ...

# %%
print("Tickets per cluster (average): {}".format((len(df)-cluster_counts[-1])/(len(labels)-1)))
# Out:
# Tickets per cluster (average): 4.65625

# %%
tmp = train.copy()
tmp.insert(len(tmp.columns), "TicketCluster", [ticket_cluster[ticketIndex(ticket)] for ticket in tmp.Ticket])
tmp.insert(len(tmp.columns), "TicketClusterSize", [cluster_counts[cluster] if cluster != -1 else 1
                                                   for cluster in tmp.TicketCluster])
print_and_plot(tmp, "TicketCluster")
# Out:
# Survived              0         1  Count
# TicketCluster
# -1             0.557185  0.442815    341
#  0             1.000000  0.000000      4
#  1             0.800000  0.200000     10
#  2             0.666667  0.333333     36
#  3             0.333333  0.666667      3
#  4             0.250000  0.750000      4
#  5             1.000000  0.000000      6
#  6             0.250000  0.750000      4
#  7             0.500000  0.500000      2
#  8             0.500000  0.500000      2
#  9             1.000000  0.000000      2
#  10            0.821429  0.178571     28
#  11            1.000000  0.000000      3
#  12            0.857143  0.142857      7
#  13            1.000000  0.000000      4
#  14            0.571429  0.428571     49
#  15            0.000000  1.000000      1
#  16            0.500000  0.500000      6
#  17            0.000000  1.000000      2
#  18            0.936170  0.063830     47
#  19            1.000000  0.000000      2
# ...

# %%
print_and_plot(tmp, "TicketClusterSize", step=10)
# Out:
# Survived                  0         1  Count
# TicketClusterSize
# (0, 10)            0.582111  0.417889    682
# (10, 20)           0.673469  0.326531     49
# (20, 30)           0.821429  0.178571     28
# (30, 40)           0.666667  0.333333     36
# (50, 60)           0.750000  0.250000     96

# %%
people_on_cluster = {}
for cluster, tickets in cluster_tickets.items():
    if cluster == -1: continue
    people_on_cluster[cluster] = 0
    for ticket in tickets:
        people_on_cluster[cluster] += len(fulldata[fulldata.Ticket == ticket])
tmp.insert(len(tmp.columns), "PeopleOnCluster", [people_on_cluster[row.TicketCluster] if row.TicketCluster != -1 else
                                                 len(fulldata[fulldata.Ticket == row.Ticket])
                                                 for ind, row in tmp.iterrows()])
print_and_plot(tmp, "PeopleOnCluster")
# Out:
# Survived                0         1  Count
# PeopleOnCluster
# 0                0.652727  0.347273    550
# 1                0.730263  0.269737    152
# 2                0.435897  0.564103     78
# 3                0.296296  0.703704     54
# 4                0.240000  0.760000     25
# 5                0.333333  0.666667      3
# 6                0.500000  0.500000      4
# 7                1.000000  0.000000      5
# 8                0.615385  0.384615     13
# 11               1.000000  0.000000      7

# %% [markdown]
# ### Расчёт индекса выживаемости по кластеру

# %%
tmp = train.copy()
tmp.insert(len(tmp.columns), "TicketCluster", [ticket_cluster[ticketIndex(ticket)] for ticket in tmp.Ticket])

cluster_survival = {cluster: {"survived": 0, "perished": 0} for cluster in labels if cluster != -1}
for ind, row in tmp.iterrows():
    if row.TicketCluster == -1: continue
    if row.Survived:
        cluster_survival[row.TicketCluster]["survived"] += 1
    else:
        cluster_survival[row.TicketCluster]["perished"] += 1

def clusterSurvival(row):
    index = lambda surv, per: surv - per
    try:
        info = cluster_survival[row.TicketCluster]
    except KeyError:
        return 0
    if row.Survived:
        return index(info["survived"]-1, info["perished"])
    else:
        return index(info["survived"], info["perished"]-1)

tmp.insert(len(tmp.columns), "ClusterSurvival", [clusterSurvival(row) for ind, row in tmp.iterrows()])
#tmp.ClusterSurvival = [(-2 if s < -2 else 2 if s > 2 else s) for s in tmp.ClusterSurvival]
print_and_plot(tmp, "ClusterSurvival")
# Out:
# Survived                0         1  Count
# ClusterSurvival
# -42              0.000000  1.000000      3
# -40              1.000000  0.000000     44
# -19              0.000000  1.000000      5
# -17              1.000000  0.000000     23
# -13              0.000000  1.000000     12
# -11              1.000000  0.000000     24
# -10              0.000000  1.000000      1
# -8               0.322581  0.677419     31
# -7               0.000000  1.000000      2
# -6               0.875000  0.125000     40
# -5               1.000000  0.000000     26
# -4               0.862069  0.137931     29
# -3               0.615385  0.384615     13
# -2               0.609756  0.390244     41
# -1               0.691176  0.308824     68
#  0               0.581907  0.418093    409
#  1               0.456522  0.543478     46
#  2               0.250000  0.750000     28
#  3               0.230769  0.769231     13
#  4               1.000000  0.000000      6
# ...
